# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
pd.set_option('display.max_columns', 500)
from sqlalchemy import create_engine
engine = create_engine("postgresql://postgres:password@localhost/sachacks2020")

inv_map = {v.upper(): k.upper() for k, v in state_convertion.items()}
import warnings
warnings.filterwarnings('ignore')

# %%
state_convertion
# Out:
# {'AL': 'Alabama',
#  'AK': 'Alaska',
#  'AS': 'American Samoa',
#  'AZ': 'Arizona',
#  'AR': 'Arkansas',
#  'CA': 'California',
#  'CO': 'Colorado',
#  'CT': 'Connecticut',
#  'DE': 'Delaware',
#  'DC': 'District Of Columbia',
#  'FM': 'Federated States Of Micronesia',
#  'FL': 'Florida',
#  'GA': 'Georgia',
#  'GU': 'Guam',
#  'HI': 'Hawaii',
#  'ID': 'Idaho',
#  'IL': 'Illinois',
#  'IN': 'Indiana',
#  'IA': 'Iowa',
#  'KS': 'Kansas',
#  'KY': 'Kentucky',
#  'LA': 'Louisiana',
#  'ME': 'Maine',
#  'MH': 'Marshall Islands',
#  'MD': 'Maryland',
#  'MA': 'Massachusetts',
#  'MI': 'Michigan',
#  'MN': 'Minnesota',
#  'MS': 'Mississippi',
#  'MO': 'Missouri',
#  'MT': 'Montana',
#  'NE': 'Nebraska',
#  'NV': 'Nevada',
#  'NH': 'New Hampshire',
#  'NJ': 'New Jersey',
#  'NM': 'New Mexico',
#  'NY': 'New York',
#  'NC': 'North Carolina',
#  'ND': 'North Dakota',
#  'MP': 'Northern Mariana Islands',
#  'OH': 'Ohio',
#  'OK': 'Oklahoma',
#  'OR': 'Oregon',
#  'PW': 'Palau',
#  'PA': 'Pennsylvania',
#  'PR': 'Puerto Rico',
#  'RI': 'Rhode Island',
#  'SC': 'South Carolina',
#  'SD': 'South Dakota',
#  'TN': 'Tennessee',
#  'TX': 'Texas',
#  'UT': 'Utah',
#  'VT': 'Vermont',
#  'VI': 'Virgin Islands',
#  'VA': 'Virginia',
#  'WA': 'Washington',
#  'WV': 'West Virginia',
#  'WI': 'Wisconsin',
#  'WY': 'Wyoming'}

# %%
df = pd.read_excel("CMS_AllData_2017_21columns_Sheet1.xlsx")
print(len(df))
df.head()
# Out:
# 646387
#    Unnamed: 0         npi nppes_provider_last_org_name  \
# 0           0  1245201227                     GRUENDEL
# 1           1  1649591223                       RAMOSO
# 2           2  1548398597                        GLENN
# 3           3  1780674101                     MITCHELL
# 4           4  1861502288                  SEYEDKAZEMI
#
#   nppes_provider_first_name nppes_provider_city nppes_provider_state  \
# 0                      JOHN              CARMEL                   NY
# 1                    WESLEY              EUGENE                   OR
# 2                     TERRI                ACME                   MI
# 3                  KIMBERLY               CABOT                   AR
# 4                   MAHSHID         LOS ANGELES                   CA
#
#   specialty_description description_flag      drug_name          generic_name  \
# 0            Cardiology                S      TOPROL XL  METOPROLOL SUCCINATE
# 1       Family Practice                S       NOVOFINE  PEN NEEDLE, DIABETIC
# 2    Nurse Practitioner                S   VALACYCLOVIR      VALACYCLOVIR HCL
# 3             Optometry                S        LUMIGAN           BIMATOPROST
# 4            Pharmacist                T  CLONIDINE HCL         CLONIDINE HCL
#
#    bene_count  total_claim_count  total_30_day_fill_count  total_day_supply  \
# 0         NaN                 31                     85.0              2550
# 1         NaN                 24                     31.3               770
# 2         NaN                 19                     39.5              1095
# 3        14.0                 31                     45.5              1316
# 4         NaN                 30                     36.0               979
#
#    total_drug_cost  bene_count_ge65 bene_count_ge65_suppress_flag  \
# 0          1492.02              NaN                             *
# 1          1037.23              NaN                             *
# 2          1089.22              NaN                             #
# 3          7936.87              NaN                             #
# 4           207.07              NaN                             *
#
#    total_claim_count_ge65 ge65_suppress_flag  total_30_day_fill_count_ge65  \
# 0                    31.0                NaN                          85.0
# 1                    24.0                NaN                          31.3
# 2                     NaN                  #                           NaN
# 3                     NaN                  #                           NaN
# 4                     NaN                  *                           NaN
#
#    total_day_supply_ge65  total_drug_cost_ge65
# 0                 2550.0               1492.02
# 1                  770.0               1037.23
# 2                    NaN                   NaN
# 3                    NaN                   NaN
# 4                    NaN                   NaN

# %%
sns.heatmap(df.isnull(), cbar=False)

# %% [markdown]
# # Obtain row with bene_count that is not null

# %%
df_been_count = df.dropna(subset=["bene_count"])
print(len(df_been_count))

columns_to_drop = ["Unnamed: 0",'total_30_day_fill_count',
       'bene_count_ge65', 'bene_count_ge65_suppress_flag',
       'total_claim_count_ge65', 'ge65_suppress_flag',
       'total_30_day_fill_count_ge65', 'total_day_supply_ge65',
       'total_drug_cost_ge65','description_flag']

df_been_count.drop(columns=columns_to_drop, inplace=True)
df_been_count.dropna(inplace=True)
df_been_count.rename(columns = {
    "nppes_provider_last_org_name" : "provider_last_name",
    "nppes_provider_first_name" : "provider_first_name",
    "nppes_provider_city": "provider_city",
    "bene_count"        : "number_opioid_users_unique",
    "total_claim_count" : "number_opioid_ordered",
    "nppes_provider_state" : "provider_state",
    "specialty_description": "provider_job"
}, inplace=True)

def state_convert(x):
    try:
        return state_convertion[x].upper()
    except:
        return None

df_been_count["provider_state"] = df_been_count["provider_state"].apply(state_convert)
df_been_count.reset_index(drop=True, inplace=True)
df_been_count.head()
# Out:
# 258810
#           npi provider_last_name provider_first_name   provider_city  \
# 0  1780674101           MITCHELL            KIMBERLY           CABOT
# 1  1952306417          PARKHURST             REBECCA            ERIE
# 2  1396811725             HERSON               PERRY  WILLISTON PARK
# 3  1487749305             TRENCH                JOHN     TERRE HAUTE
# 4  1679736003           TASCHNER            JENNIFER      FORT MYERS
#
#   provider_state         provider_job            drug_name  \
# 0       ARKANSAS            Optometry              LUMIGAN
# 1   PENNSYLVANIA  Physician Assistant          LAMOTRIGINE
# 2       NEW YORK        Endocrinology     METFORMIN HCL ER
# 3        INDIANA             Podiatry    CIPROFLOXACIN HCL
# 4        FLORIDA              Dentist  DOXYCYCLINE HYCLATE
#
#           generic_name  number_opioid_users_unique  number_opioid_ordered  \
# 0          BIMATOPROST                        14.0                     31
# 1          LAMOTRIGINE                        15.0                     51
# 2        METFORMIN HCL                        19.0                     50
# 3    CIPROFLOXACIN HCL                        18.0                     20
# 4  DOXYCYCLINE HYCLATE                        22.0                     23
#
#    total_day_supply  total_drug_cost
# 0              1316          7936.87
# 1              2785           990.51
# 2              3900          1254.87
# 3               199           128.40
# 4               390           327.67

# %%
#  FILTER OUT THE OPIOIDS
df_opoiods_list = pd.read_excel("OpioidMedicationsIntheDataSet.xlsx")
df_opoiods_list.head()
rows_to_drop = []
for i in range(len(df_been_count.drug_name)):
    for opiod in df_opoiods_list["Opioid Medications"]:

        if df_been_count.drug_name.iloc[i].lower() in opiod.lower():
            rows_to_drop.append(i)
            break
        
new_rows_to_drop = [x for i in list(df_been_count.index) if i not in rows_to_drop]
df_been_count_v1 = df_been_count.drop(new_rows_to_drop)
df_been_count_v1.head()

# %%
new_rows_to_drop = [i for i in list(df_been_count.index) if i not in rows_to_drop]
df_been_count_v1 = df_been_count.drop(new_rows_to_drop)
df_been_count_v1.head()
# Out:
#             npi provider_last_name provider_first_name provider_city  \
# 49   1568542710              COYNE             HEATHER     LANCASTER
# 65   1609855485             SENICA             KAROLYN   SPRINGFIELD
# 107  1245204569          DONALDSON             WILLIAM    PITTSBURGH
# 116  1487818712             DOWELL              ROBERT     KNOXVILLE
# 137  1750367975              FAHIM             MOHAMED        ELKINS
#
#     provider_state         provider_job         drug_name      generic_name  \
# 49    PENNSYLVANIA  Physician Assistant     OXYCODONE HCL     OXYCODONE HCL
# 65        ILLINOIS   Orthopedic Surgery      TRAMADOL HCL      TRAMADOL HCL
# 107   PENNSYLVANIA   Orthopedic Surgery     OXYCODONE HCL     OXYCODONE HCL
# 116      TENNESSEE   Nurse Practitioner  PROMETHAZINE HCL  PROMETHAZINE HCL
# 137  WEST VIRGINIA       Anesthesiology      TRAMADOL HCL      TRAMADOL HCL
#
#      number_opioid_users_unique  number_opioid_ordered  total_day_supply  \
# 49                         13.0                     62              1644
# 65                        159.0                    241              1911
# 107                        26.0                     31               403
# 116                        37.0                    174               946
# 137                        21.0                    101              3230
#
#      total_drug_cost
# 49           2521.73
# 65            740.68
# 107           540.37
# 116          1143.84
# 137           872.28

# %%
# INSERT TO DATABASE
df_been_count_v1.to_sql(name="drugs", con=engine, index=False, if_exists="replace")

# %% [markdown]
# # DEATH COUNTS
# # DEATH COUNTS
# # DEATH COUNTS
# # DEATH COUNTS
# # DEATH COUNTS
# # DEATH COUNTS
# # DEATH COUNTS

# %%
df_deaths = pd.read_csv("deaths/df_deaths_original.csv")
drop_columns = ["Predicted Value", "Percent Complete", "Percent Pending Investigation", "Footnote","State Name"]

df_deaths.drop(columns=drop_columns, inplace=True)
print(len(df_deaths))
df_deaths.rename(columns={"Data Value": "Data_Value"}, inplace=True)
df_deaths["Data_Value"] = df_deaths["Data_Value"].astype(int)
df_deaths["State"] = df_deaths["State"].apply(state_convert)
df_deaths.drop(columns=["Indicator"], inplace=True)
df_deaths.dropna(inplace=True)
df_deaths.head()
# Out:
# 10320
#     State  Year     Month  Data_Value
# 0  ALASKA  2015   January        4034
# 1  ALASKA  2015  February        4084
# 2  ALASKA  2015     March        4101
# 3  ALASKA  2015     April        4133
# 4  ALASKA  2015       May        4196

# %%
df_deaths.to_sql(name="death_count", con=engine, if_exists="replace", index=False)

# %% [markdown]
# # CRIME RATE

# %%
df_crime_rate = pd.read_csv("crime_origin/crime_and_incarceration_by_state.csv")
df_crime_rate.head()
# Out:
#   jurisdiction  includes_jails  year  prisoner_count crime_reporting_change  \
# 0      FEDERAL           False  2001          149852                    NaN
# 1      ALABAMA           False  2001           24741                  False
# 2       ALASKA            True  2001            4570                  False
# 3      ARIZONA           False  2001           27710                  False
# 4     ARKANSAS           False  2001           11489                  False
#
#   crimes_estimated  state_population  violent_crime_total  \
# 0              NaN               NaN                  NaN
# 1            False         4468912.0              19582.0
# 2            False          633630.0               3735.0
# 3            False         5306966.0              28675.0
# 4            False         2694698.0              12190.0
#
#    murder_manslaughter  rape_legacy  rape_revised  robbery  agg_assault  \
# 0                  NaN          NaN           NaN      NaN          NaN
# 1                379.0       1369.0           NaN   5584.0      12250.0
# 2                 39.0        501.0           NaN    514.0       2681.0
# 3                400.0       1518.0           NaN   8868.0      17889.0
# 4                148.0        892.0           NaN   2181.0       8969.0
#
#    property_crime_total  burglary   larceny  vehicle_theft
# 0                   NaN       NaN       NaN            NaN
# 1              173253.0   40642.0  119992.0        12619.0
# 2               23160.0    3847.0   16695.0         2618.0
# 3              293874.0   54821.0  186850.0        52203.0
# 4               99106.0   22196.0   69590.0         7320.0

# %%
df_crime_rate_nona = df_crime_rate.dropna(subset=['jurisdiction', 'includes_jails', 'year', 'prisoner_count', 'crime_reporting_change', 'crimes_estimated', 'state_population'])
df_crime_rate_nona.drop(columns=["includes_jails", "crime_reporting_change", "crimes_estimated"], inplace = True)
df_crime_rate_nona.fillna(0, inplace = True)
df_crime_rate_nona.head()
# Out:
#   jurisdiction  year  prisoner_count  state_population  violent_crime_total  \
# 1      ALABAMA  2001           24741         4468912.0              19582.0
# 2       ALASKA  2001            4570          633630.0               3735.0
# 3      ARIZONA  2001           27710         5306966.0              28675.0
# 4     ARKANSAS  2001           11489         2694698.0              12190.0
# 5   CALIFORNIA  2001          157142        34600463.0             212867.0
#
#    murder_manslaughter  rape_legacy  rape_revised  robbery  agg_assault  \
# 1                379.0       1369.0           0.0   5584.0      12250.0
# 2                 39.0        501.0           0.0    514.0       2681.0
# 3                400.0       1518.0           0.0   8868.0      17889.0
# 4                148.0        892.0           0.0   2181.0       8969.0
# 5               2206.0       9960.0           0.0  64614.0     136087.0
#
#    property_crime_total  burglary   larceny  vehicle_theft
# 1              173253.0   40642.0  119992.0        12619.0
# 2               23160.0    3847.0   16695.0         2618.0
# 3              293874.0   54821.0  186850.0        52203.0
# 4               99106.0   22196.0   69590.0         7320.0
# 5             1134189.0  232273.0  697739.0       204177.0

# %%
df_crime_rate_nona_grouped = df_crime_rate_nona.groupby(by=["year", "jurisdiction"]).sum()
df_crime_rate_nona_grouped.to_csv("crime_origin/crime_rate_final.csv")
df_crime_rate_nona_grouped.to_sql(name="crime_rate", con=engine, if_exists="replace")
df_crime_rate_nona_grouped.head()
# Out:
#                    prisoner_count  state_population  violent_crime_total  \
# year jurisdiction
# 2001 ALABAMA                24741         4468912.0              19582.0
#      ALASKA                  4570          633630.0               3735.0
#      ARIZONA                27710         5306966.0              28675.0
#      ARKANSAS               11489         2694698.0              12190.0
#      CALIFORNIA            157142        34600463.0             212867.0
#
#                    murder_manslaughter  rape_legacy  rape_revised  robbery  \
# year jurisdiction
# 2001 ALABAMA                     379.0       1369.0           0.0   5584.0
#      ALASKA                       39.0        501.0           0.0    514.0
#      ARIZONA                     400.0       1518.0           0.0   8868.0
#      ARKANSAS                    148.0        892.0           0.0   2181.0
#      CALIFORNIA                 2206.0       9960.0           0.0  64614.0
#
#                    agg_assault  property_crime_total  burglary   larceny  \
# year jurisdiction
# 2001 ALABAMA           12250.0              173253.0   40642.0  119992.0
#      ALASKA             2681.0               23160.0    3847.0   16695.0
#      ARIZONA           17889.0              293874.0   54821.0  186850.0
#      ARKANSAS           8969.0               99106.0   22196.0   69590.0
#      CALIFORNIA       136087.0             1134189.0  232273.0  697739.0
#
#                    vehicle_theft
# year jurisdiction
# 2001 ALABAMA             12619.0
#      ALASKA               2618.0
#      ARIZONA             52203.0
#      ARKANSAS             7320.0
#      CALIFORNIA         204177.0

# %%
df_crime_rate_nona_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 799 entries, (2001, 'ALABAMA') to (2016, 'WYOMING')
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   prisoner_count        799 non-null    int64
#  1   state_population      799 non-null    float64
#  2   violent_crime_total   799 non-null    float64
#  3   murder_manslaughter   799 non-null    float64
#  4   rape_legacy           799 non-null    float64
#  5   rape_revised          799 non-null    float64
#  6   robbery               799 non-null    float64
#  7   agg_assault           799 non-null    float64
#  8   property_crime_total  799 non-null    float64
#  9   burglary              799 non-null    float64
#  10  larceny               799 non-null    float64
#  11  vehicle_theft         799 non-null    float64
# dtypes: float64(11), int64(1)
# memory usage: 77.1+ KB

# %% [markdown]
# # ANALYZATION

# %%
df_been_count_v1_ananlyze = df_been_count_v1.drop(columns=["npi", "provider_last_name", "provider_first_name", "provider_city", "generic_name"])
df_been_count_v1_ananlyze.head()
# Out:
#     provider_state         provider_job         drug_name  \
# 49    PENNSYLVANIA  Physician Assistant     OXYCODONE HCL
# 65        ILLINOIS   Orthopedic Surgery      TRAMADOL HCL
# 107   PENNSYLVANIA   Orthopedic Surgery     OXYCODONE HCL
# 116      TENNESSEE   Nurse Practitioner  PROMETHAZINE HCL
# 137  WEST VIRGINIA       Anesthesiology      TRAMADOL HCL
#
#      number_opioid_users_unique  number_opioid_ordered  total_day_supply  \
# 49                         13.0                     62              1644
# 65                        159.0                    241              1911
# 107                        26.0                     31               403
# 116                        37.0                    174               946
# 137                        21.0                    101              3230
#
#      total_drug_cost
# 49           2521.73
# 65            740.68
# 107           540.37
# 116          1143.84
# 137           872.28

# %%
df_crime_rate_analyze = df_crime_rate.drop(columns=["includes_jails", "prisoner_count", "crime_reporting_change", "crimes_estimated"]).dropna()
df_crime_rate_analyze = df_crime_rate_analyze[df_crime_rate_analyze["year"] == 2015]
df_crime_rate_analyze.head()
# Out:
#     jurisdiction  year  state_population  violent_crime_total  \
# 715      ALABAMA  2015         4858979.0              22952.0
# 716       ALASKA  2015          738432.0               5392.0
# 717      ARIZONA  2015         6828065.0              28012.0
# 718     ARKANSAS  2015         2978204.0              15526.0
# 719   CALIFORNIA  2015        39144818.0             166883.0
#
#      murder_manslaughter  rape_legacy  rape_revised  robbery  agg_assault  \
# 715                348.0       1456.0        2039.0   4611.0      15954.0
# 716                 59.0        650.0         901.0    761.0       3671.0
# 717                309.0       2294.0        3108.0   6360.0      18235.0
# 718                181.0       1300.0        1931.0   2098.0      11316.0
# 719               1861.0       9387.0       12811.0  52862.0      99349.0
#
#      property_crime_total  burglary   larceny  vehicle_theft
# 715              144746.0   35255.0   99156.0        10335.0
# 716               20806.0    3511.0   15249.0         2046.0
# 717              207107.0   37957.0  152365.0        16785.0
# 718               96836.0   22640.0   68424.0         5772.0
# 719             1024914.0  197404.0  656517.0       170993.0

# %%
df_been_count_v1_ananlyze_grouped = df_been_count_v1_ananlyze.groupby(by=["provider_state"]).sum()[["number_opioid_users_unique", "number_opioid_ordered"]]
df_been_count_v1_ananlyze_grouped.reset_index(inplace=True)
df_been_count_v1_ananlyze_grouped.head()
# Out:
#   provider_state  number_opioid_users_unique  number_opioid_ordered
# 0        ALABAMA                      4378.0                  14822
# 1         ALASKA                       200.0                    683
# 2        ARIZONA                      5975.0                  16665
# 3       ARKANSAS                      2525.0                   8384
# 4     CALIFORNIA                     22174.0                  55590

# %%
df_crime_rate_analyze_grouped = df_crime_rate_analyze.groupby(by=["jurisdiction"]).sum()

# Top 4 crimes
high_crime = ["larceny", "burglary", "violent_crime_total", "agg_assault", "vehicle_theft"]
# 
df_crime_rate_analyze_v1 = df_crime_rate_analyze[["jurisdiction"] + high_crime].groupby("jurisdiction").sum().reset_index()
df_crime_rate_analyze_v1["number_opioid_users_unique"] = None
df_crime_rate_analyze_v1["number_opioid_ordered"] = None

# %%
for i in range(len(df_crime_rate_analyze_v1.jurisdiction)):
    for j in range(len(df_been_count_ananlyze_grouped.provider_state)):
        
        if df_crime_rate_analyze_v1.jurisdiction.iloc[i] == df_been_count_ananlyze_grouped.provider_state.iloc[j]:
            df_crime_rate_analyze_v1.number_opioid_users_unique.iloc[i] = df_been_count_ananlyze_grouped.number_opioid_users_unique.iloc[j]
            df_crime_rate_analyze_v1.number_opioid_ordered.iloc[i] = df_been_count_ananlyze_grouped.number_opioid_ordered.iloc[j]

df_crime_rate_analyze_v1.head()
# Out:
#   jurisdiction   larceny  burglary  violent_crime_total  agg_assault  \
# 0      ALABAMA   99156.0   35255.0              22952.0      15954.0
# 1       ALASKA   15249.0    3511.0               5392.0       3671.0
# 2      ARIZONA  152365.0   37957.0              28012.0      18235.0
# 3     ARKANSAS   68424.0   22640.0              15526.0      11316.0
# 4   CALIFORNIA  656517.0  197404.0             166883.0      99349.0
#
#    vehicle_theft number_opioid_users_unique number_opioid_ordered
# 0        10335.0                     155356                512023
# 1         2046.0                       3267                 10064
# 2        16785.0                     145457                404993
# 3         5772.0                      87345                325387
# 4       170993.0                     743218               2334963

# %%
df_crime_rate_analyze_v1["number_opioid_users_unique"] = df_crime_rate_analyze_v1["number_opioid_users_unique"].astype(int)
df_crime_rate_analyze_v1["number_opioid_ordered"] = df_crime_rate_analyze_v1["number_opioid_ordered"].astype(int)

# %%
# PROVEN IN MULTIPLE STATES NUMBERS OF PEOPLE TAKING OPIOIDS IS CORR WITH NUMBER OF CRIMES

corr = df_crime_rate_analyze_v1.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_46dd9130_564e_11ea_af44_701ce7243b59row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row0_col1 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row0_col2 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row0_col3 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row0_col4 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row0_col5 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row0_col6 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row1_col0 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row1_col2 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row1_col3 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row1_col4 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row1_col5 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row1_col6 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row2_col0 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row2_col1 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row2_col3 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row2_col4 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row2_col5 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row2_col6 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row3_col0 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row3_col1 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row3_col2 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row3_col4 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row3_col5 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row3_col6 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row5_col0 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row5_col1 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row5_col2 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row5_col3 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row5_col4 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row5_col6 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row6_col0 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row6_col1 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row6_col2 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row6_col3 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row6_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row6_col5 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_46dd9130_564e_11ea_af44_701ce7243b59row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_46dd9130_564e_11ea_af44_701ce7243b59" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >larceny</th>        <th class="col_heading level0 col1" >burglary</th>        <th class="col_heading level0 col2" >violent_crime_total</th>        <th class="col_heading level0 col3" >agg_assault</th>        <th class="col_heading level0 col4" >vehicle_theft</th>        <th class="col_heading level0 col5" >number_opioid_users_unique</th>        <th class="col_heading level0 col6" >number_opioid_ordered</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_46dd9130_564e_11ea_af44_701ce7243b59level0_row0" class="row_heading level0 row0" >larceny</th>
#                         <td id="T_46dd9130_564e_11ea_af44_701ce7243b59row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_46dd9130_564e_11ea_af44_701ce7243b59row0_col1" class="data row0 col1" >0.985599</td>
#                         <td id="T_46dd9130_564e_11ea_af44_701ce7243b59row0_col2" class="data row0 col2" >0.975323</td>
#                         <td id="T_46dd9130_564e_11ea_af44_701ce7243b59row0_col3" class="data row0 col3" >0.963871</td>
#                         <td id="T_46dd9130_564e_11ea_af44_701ce7243b59row0_col4" class="data row0 col4" >0.890910</td>
#                         <td id="T_46dd9130_564e_11ea_af44_701ce7243b59row0_col5" class="data row0 col5" >0.951695</td>

# %%
df_crime_rate_analyze_v1.larceny = df_crime_rate_analyze_v1.larceny.astype(int)
df_crime_rate_analyze_v1.burglary = df_crime_rate_analyze_v1.burglary.astype(int)
df_crime_rate_analyze_v1.violent_crime_total = df_crime_rate_analyze_v1.violent_crime_total.astype(int)
df_crime_rate_analyze_v1.vehicle_theft = df_crime_rate_analyze_v1.vehicle_theft.astype(int)
df_crime_rate_analyze_v1.agg_assault = df_crime_rate_analyze_v1.agg_assault.astype(int) 
df_crime_rate_analyze_v1.number_opioid_users_unique   = df_crime_rate_analyze_v1.number_opioid_users_unique  .astype(int) 
df_crime_rate_analyze_v1.number_opioid_ordered        = df_crime_rate_analyze_v1.number_opioid_ordered       .astype(int) 
df_crime_rate_analyze_v1.info()

df_crime_rate_analyze_v1.to_sql(name="drug_crime_analyzed", con=engine, index=False, if_exists="replace")
df_crime_rate_analyze_v1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   jurisdiction                49 non-null     object
#  1   larceny                     49 non-null     int32
#  2   burglary                    49 non-null     int32
#  3   violent_crime_total         49 non-null     int32
#  4   agg_assault                 49 non-null     int32
#  5   vehicle_theft               49 non-null     int32
#  6   number_opioid_users_unique  49 non-null     int32
#  7   number_opioid_ordered       49 non-null     int32
# dtypes: int32(7), object(1)
# memory usage: 1.8+ KB
#   jurisdiction  larceny  burglary  violent_crime_total  agg_assault  \
# 0      ALABAMA    99156     35255                22952        15954
# 1       ALASKA    15249      3511                 5392         3671
# 2      ARIZONA   152365     37957                28012        18235
# 3     ARKANSAS    68424     22640                15526        11316
# 4   CALIFORNIA   656517    197404               166883        99349
#
#    vehicle_theft  number_opioid_users_unique  number_opioid_ordered
# 0          10335                      155356                 512023
# 1           2046                        3267                  10064
# 2          16785                      145457                 404993
# 3           5772                       87345                 325387
# 4         170993                      743218                2334963

# %% [markdown]
# # LET'S DO MACHINE LEARNING

# %%
from sklearn.linear_model import LinearRegression
# Out:
# Requirement already satisfied: scikit-learn in d:\development\programming_language\python3\lib\site-packages (0.22.1)
# Requirement already satisfied: scipy>=0.17.0 in d:\development\programming_language\python3\lib\site-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in d:\development\programming_language\python3\lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=0.11 in d:\development\programming_language\python3\lib\site-packages (from scikit-learn) (0.14.1)
# WARNING: You are using pip version 19.2.3, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
ml = df_crime_rate_analyze_v1.drop(columns=["jurisdication", "violent_crime_total"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-394-83aa2b974955> in <module>
# ----> 1 ml = df_crime_rate_analyze_v1.drop(column=["jurisdication"])
#
# TypeError: drop() got an unexpected keyword argument 'column'
